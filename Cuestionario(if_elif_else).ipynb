# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-davidiglesias31/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
marcador = 0

print("¡A jugar!")

print("Pregunta 1")

# Corrected line:
pregunta1 = float(input("Cuantos anillos de la NBA tiene Michael Jordan:"))

if pregunta1 == 6 :
  print("CORRECTO")
  marcador += 1


else:
  print("ERROR")

print("")

print("Pregunta 2")

print("con cual de estos cantantes colaboro con Milo J para hacer la cancion No No")
print("1.De la Rose")
print("2.Munic")
print("3.Bizarrap")
print("4.Trueno")
print("5.Peso Pluma")

pregunta2 = float(input("Tu respusta (marca el numero)-->"))

if pregunta2 == 2:
  print("CORRECTO")
  marcador +=  1
else:
  print("ERROR")

print("")

print("En que equipo juega actualmente Haliburton")
print("1.Chicago Bulls")
print("2.Denver Nuggets")
print("3.Dallas Mavericks")
print("4.Indiana Pacers")
print("5.Real Madrid")

pregunta3 = float(input("Tu respusta (marca el numero)-->"))

if pregunta3 == 4:
  print("CORRECTO")
  marcador += 1

else:
  print("ERROR")

print("")

print("cual es la raiz cuadrada de -1")
print("1.e")
print("2.no existe")
print("3.1")
print("4.i")
print("5.67")

pregunta4 = float(input("Tu respusta (marca el numero)-->"))

if pregunta4 == 2:
  print("CORRECTO")
  marcador += 1
else:
  print("ERROR")

print("has hecho el",marcador/4*100 ,"%")
# Out:
# ¡A jugar!
# Pregunta 1
# Cuantos anillos de la NBA tiene Michael Jordan: 6
# CORRECTO
#
# Pregunta 2
# con cual de estos cantantes colaboro con Milo J para hacer la cancion No No
# 1.De la Rose
# 2.Munic
# 3.Bizarrap
# 4.Trueno
# 5.Peso Pluma
# Tu respusta (marca el numero)-->2
# CORRECTO
#
# En que equipo juega actualmente Haliburton
# 1.Chicago Bulls
# 2.Denver Nuggets
# 3.Dallas Mavericks
# 4.Indiana Pacers
# 5.Real Madrid
# Tu respusta (marca el numero)-->4
# CORRECTO
#
# cual es la raiz cuadrada de -1
# 1.e
# 2.no existe
# 3.1
# 4.i
# 5.67
# Tu respusta (marca el numero)-->3
# CORRECTO
# has hecho el 100.0 %
